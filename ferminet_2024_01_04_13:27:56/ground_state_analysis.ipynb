# %%
import numpy as np
import jax

# Specify the file path
file_path = 'qmcjax_ckpt_009249.npz'

# Load the file
data = np.load(file_path)

# Read the variables
t_var = data['t']
params_var = data['params']
opt_state_var = data['opt_state']
mcmc_width_var = data['mcmc_width']
density_state_var = data['density_state']

# Print the variables
print(t_var)
print(params_var)
print(opt_state_var)
print(mcmc_width_var)
print(density_state_var)

# Remember to close the file after you're done
data.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import jax
#       4 # Specify the file path
#       5 file_path = 'qmcjax_ckpt_009249.npz'
#
# ModuleNotFoundError: No module named 'jax'

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Specify the file path
file_path = '/Users/ouyangxiaoyu/Desktop/ferminet/ferminet_2024_01_04_16:17:19/train_stats.csv'

# Read the file and extract the 'energy' column
df = pd.read_csv(file_path)
energy_column = df['energy']

# Plot the 'energy' column
energy_column.plot()
# 使用rolling函数计算滚动平均值
rolling_mean = energy_column.rolling(window=100).mean()

# 绘制平滑后的图像
rolling_mean.plot()

# Plot the 'energy' column
energy_column.plot()
# 使用rolling函数计算滚动平均值
rolling_mean = energy_column.rolling(window=100).mean()

# 绘制平滑后的图像
rolling_mean.plot()

# Zoom in and set the x-axis limit to the first 10,000 steps
plt.xlim(0, 10000)
# Out:
# (0.0, 10000.0)
